# %%
from torch.utils.tensorboard import SummaryWriter
from PIL import Image
import cv2
import numpy as np

writer = SummaryWriter(log_dir='logs/experiment1')
img = Image.open('/Users/cloud/code/CodeRepository/python/pytorchlearn/hymenoptera_data/train/ants/5650366_e22b7e1065.jpg')
img = np.array(img)
writer.add_image("ant", img, 2, dataformats='HWC')

for i in range(100):
    writer.add_scalar('loss/train', i, i)
writer.close()
